# %%
#!/usr/bin/env python
# coding:utf-8
import tensorflow as tf

input_x =[[1.],[5.]]
input_y =[[4.],[2.]]

x = tf.placeholder("float",[None, 1])
y_ = tf.placeholder("float",[None, 1])

a = tf.Variable([1.], name="slope")
b = tf.Variable([0.], name="y-intercept")
y = tf.mul(a, x) + b

# 誤差関数
init = tf.initialize_all_variables()

loss = tf.reduce_sum(tf.square(y_ - y))

# 勾配降下法
train_step = tf.train.GradientDescentOptimizer(0.03).minimize(loss)


with tf.Session() as sess:
	sess.run(init)
	print '初期状態'
	print '誤差' + str(sess.run(loss, feed_dict={x: input_x, y_: input_y}))
	print "slope: %f, y-intercept: %f" % (sess.run(a), sess.run(b))

    for step in range(1000):
        sess.run(train_step, feed_dict={x: input_x, y_: input_y})
        if (step+1) % 20 == 0:
			print '\nStep: %s' % (step+1)
			print '誤差' + str(sess.run(loss, feed_dict={x: input_x, y_: input_y}))
			print "slope: %f, y-intercept: %f" % (sess.run(a), sess.run(b))
# Out:
# 初期状態
# 誤差18.0
# slope: 1.000000, y-intercept: 0.000000
#
# Step: 20
# 誤差3.13032
# slope: 0.032173, y-intercept: 2.245966
#
# Step: 40
# 誤差0.752317
# slope: -0.239140, y-intercept: 3.394981
#
# Step: 60
# 誤差0.180807
# slope: -0.372117, y-intercept: 3.958278
#
# Step: 80
# 誤差0.0434538
# slope: -0.437307, y-intercept: 4.234427
#
# Step: 100
# 誤差0.0104434
# slope: -0.469265, y-intercept: 4.369806
#
# Step: 120
# 誤差0.00250988
# slope: -0.484933, y-intercept: 4.436174
#
# Step: 140
# 誤差0.000603205
# slope: -0.492613, y-intercept: 4.468710
#
# Step: 160
# 誤差0.000144958
# slope: -0.496379, y-intercept: 4.484661
#
# Step: 180
# 誤差3.48379e-05
# slope: -0.498225, y-intercept: 4.492480
#
# Step: 200
# 誤差8.37314e-06
# slope: -0.499130, y-intercept: 4.496314
#
# Step: 220
# 誤差2.01134e-06
# slope: -0.499573, y-intercept: 4.498193
#
# Step: 240
# 誤差4.83594e-07
# slope: -0.499791, y-intercept: 4.499114
#
# Step: 260
# 誤差1.16576e-07
# slope: -0.499897, y-intercept: 4.499565
#
# Step: 280
# 誤差2.78944e-08
# slope: -0.499950, y-intercept: 4.499787
#
# Step: 300
# 誤差6.70502e-09
# slope: -0.499975, y-intercept: 4.499896
#
# Step: 320
# 誤差1.62964e-09
# slope: -0.499988, y-intercept: 4.499949
#
# Step: 340
# 誤差4.12115e-10
# slope: -0.499994, y-intercept: 4.499974
#
# Step: 360
# 誤差1.01238e-10
# slope: -0.499997, y-intercept: 4.499987
#
# Step: 380
# 誤差1.66551e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 400
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 420
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 440
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 460
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 480
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 500
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 520
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 540
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 560
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 580
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 600
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 620
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 640
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 660
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 680
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 700
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 720
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 740
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 760
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 780
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 800
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 820
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 840
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 860
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 880
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 900
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 920
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 940
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 960
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 980
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
#
# Step: 1000
# 誤差1.69393e-11
# slope: -0.499999, y-intercept: 4.499995
